# %% [markdown]
# # ModHav Synthetic Dataset

# %%
# ── 0. Imports ─────────────────────────────────────────────────────────────────
from config.config import *
from config.experiments import ExperimentConfig

import src.data.saving as saving
import src.utils.visuals as visuals

from src.data.preprocessing import preprocess_synthetic
from src.data.synthetic import ModHav_synthetic_dataset
from src.data.saving import candidate_exists, svm_exists, load_parameter_train, load_svm_results
from src.data.subsets import subset_random, subset_nystrom_global, subset_nystrom_stratified
from src.kernel.quantum_kernel import quantum_kernel_matrix_cross
from src.optimization.pipeline import get_candidate, get_svm_results
from src.optimization.classical_base import classical_baseline
from src.utils.visuals import *

# %%
# ── 1. Data Import ────────────────────────────────────────────────────────────
X, y = ModHav_synthetic_dataset(seed=45)
X_train, X_test, y_train, y_test = preprocess_synthetic(X, y, N_QUBITS)

print(f"Dataset  : ModHav Synthetic, 20 per class")
print(f"Train    : {X_train.shape}  |  Test: {X_test.shape}")

RESULTS_DIR = 'Results/ModHav Synthetic'
saving.RESULTS_DIR = RESULTS_DIR
visuals.RESULTS_DIR = RESULTS_DIR
# Out:
# Dataset  : ModHav Synthetic, 20 per class
# Train    : (28, 4)  |  Test: (12, 4)

# %%
# ── 2. Dataset structure ─────────────────────────────────────────────────────────
graph_dataset("ModHav Synthetic", X, y, X_train, y_train)

# %%
# ── 3. Experiments ─────────────────────────────────────────────────────────────
# This is the main section to edit. Each ExperimentConfig defines one run.
# Comment out any you don't want to include.
#
# name             → used as the Results subfolder name; must be unique
# optimizer        → 'optuna' or 'mealpy'
# variant          → 'geometric' or 'haar'
# subset_method    → 'random', 'nystrom_global', or 'nystrom_stratified'
# subset_kwargs    → passed to the chosen subset function
# optimizer_kwargs → passed to the chosen optimizer
# load_from        → (optional) load candidate from a different experiment name

EXPERIMENTS: list[ExperimentConfig] = [
    # ──– OPTUNA ────────────────────────────────────────────────────────────────
    ExperimentConfig(
        name             = 'optuna',
        optimizer        = 'optuna',
        variant          = 'haar',
        subset_method    = 'none',
        subset_kwargs    = {'n_sample': N_POINTS, 'seed': SEED},
        optimizer_kwargs = {'n_trials': 100},
    ),
    
    ExperimentConfig(
        name             = 'optuna2',
        optimizer        = 'optuna',
        variant          = 'haar',
        subset_method    = 'none',
        subset_kwargs    = {'n_sample': N_POINTS, 'seed': SEED},
        optimizer_kwargs = {'n_trials': 100},
    )
]

# %%
# ── 4. Run ─────────────────────────────────────────────────────────────────────
# Cached results are reused automatically; delete Results/{name}/svm.pkl or
# Results/{name}/candidate.pkl to force a fresh run for that experiment.
 
summary = {}   # name → {accuracy, cv_acc, g_best, best_C}

# ── Classical baseline ──────────────────────────────────────────────────────
BASELINE = 'Classical_baseline'
if svm_exists(BASELINE):
    print(f"\nLoaded results of SVM for '{BASELINE}'")
    baseline_res = load_svm_results(BASELINE)
else:
    baseline_res = classical_baseline(X_train, y_train, X_test, y_test, name=BASELINE)
 
summary[BASELINE] = {
    'accuracy': baseline_res['accuracy'],
    'cv_acc':   float(baseline_res['best_cv_accuracy']),
    'best_C':   baseline_res['best_C'],
    'g_best':   float('nan'),
}

# ── Quantum experiments ─────────────────────────────────────────────────────
for config in EXPERIMENTS:
    print(f"\n{'─' * 60}")
    print(f" {config.name}  [{config.optimizer} + {config.subset_method}]")
    print(f"{'─' * 60}")

    # Step 1: Candidate (train or load from cache)
    candidate, K_train, K_classical, X_sub, y_sub = get_candidate(config, X_train, y_train)
    g_best = load_parameter_train(config.load_from or config.name).get('g_best', float('nan'))
    
    # Step 2: SVM (run or load from cache)
    K_test = None
    if not svm_exists(config.name):
        print("Computing cross-kernel (test × subset)…")
        K_test = quantum_kernel_matrix_cross(X_test, X_sub, candidate)
    
    results = get_svm_results(config, K_train, y_sub, K_test, y_test)
    
    summary[config.name] = {
        'accuracy': results['accuracy'],
        'cv_acc':   float(results['best_cv_accuracy']),
        'best_C':   results['best_C'],
        'g_best':   g_best,
    }
# Out:
# [I 2026-08-20 12:53:42,307] A new study created in memory with name: no-name-9c63d193-911a-4504-a2cd-0ca84d8a7923
# Loaded results of SVM for 'Classical_baseline'
#
# ────────────────────────────────────────────────────────────
#  optuna  [optuna + none]
# ────────────────────────────────────────────────────────────
# Loading cached candidate for 'optuna'
# Loading cached SVM results for 'optuna'
#
# ────────────────────────────────────────────────────────────
#  optuna2  [optuna + none]
# ────────────────────────────────────────────────────────────
# [I 2026-08-20 12:53:44,759] Trial 0 finished with value: 7.1954168608811955 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'RZ', 'gate_5': 'RY', 'gate_6': 'CNOT', 'gate_7': 'H', 'gate_8': 'CNOT', 'gate_9': 'I', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'CNOT', 'gate_14': 'I', 'gate_15': 'RZ'}. Best is trial 0 with value: 7.1954168608811955.
# [I 2026-08-20 12:53:47,152] Trial 1 finished with value: 6.064256919406774 and parameters: {'gate_0': 'CNOT', 'gate_1': 'H', 'gate_2': 'RZ', 'gate_3': 'H', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'CNOT', 'gate_8': 'RY', 'gate_9': 'CNOT', 'gate_10': 'RZ', 'gate_11': 'I', 'gate_12': 'CNOT', 'gate_13': 'H', 'gate_14': 'RZ', 'gate_15': 'RY'}. Best is trial 0 with value: 7.1954168608811955.
# [I 2026-08-20 12:53:49,465] Trial 2 finished with value: 7.273855352699582 and parameters: {'gate_0': 'RX', 'gate_1': 'RX', 'gate_2': 'RY', 'gate_3': 'I', 'gate_4': 'I', 'gate_5': 'CNOT', 'gate_6': 'H', 'gate_7': 'RX', 'gate_8': 'RX', 'gate_9': 'CNOT', 'gate_10': 'CNOT', 'gate_11': 'CNOT', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'CNOT'}. Best is trial 2 with value: 7.273855352699582.
# [I 2026-08-20 12:53:51,746] Trial 3 finished with value: 8.9261128521907 and parameters: {'gate_0': 'H', 'gate_1': 'RY', 'gate_2': 'RY', 'gate_3': 'H', 'gate_4': 'I', 'gate_5': 'RY', 'gate_6': 'RY', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RX', 'gate_15': 'CNOT'}. Best is trial 3 with value: 8.9261128521907.
# [I 2026-08-20 12:53:54,068] Trial 4 finished with value: 7.278120545134454 and parameters: {'gate_0': 'H', 'gate_1': 'H', 'gate_2': 'RY', 'gate_3': 'RZ', 'gate_4': 'CNOT', 'gate_5': 'H', 'gate_6': 'CNOT', 'gate_7': 'I', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RZ', 'gate_11': 'RX', 'gate_12': 'H', 'gate_13': 'RZ', 'gate_14': 'RX', 'gate_15': 'RX'}. Best is trial 3 with value: 8.9261128521907.
# [I 2026-08-20 12:53:55,841] Trial 5 finished with value: 6.12896951930439 and parameters: {'gate_0': 'H', 'gate_1': 'RZ', 'gate_2': 'RY', 'gate_3': 'H', 'gate_4': 'RZ', 'gate_5': 'RX', 'gate_6': 'I', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'H', 'gate_10': 'H', 'gate_11': 'RZ', 'gate_12': 'H', 'gate_13': 'I', 'gate_14': 'I', 'gate_15': 'CNOT'}. Best is trial 3 with value: 8.9261128521907.
# [I 2026-08-20 12:53:57,884] Trial 6 finished with value: 7.114421965639592 and parameters: {'gate_0': 'RZ', 'gate_1': 'H', 'gate_2': 'RY', 'gate_3': 'RY', 'gate_4': 'I', 'gate_5': 'I', 'gate_6': 'I', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'CNOT', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'H', 'gate_14': 'RY', 'gate_15': 'RY'}. Best is trial 3 with value: 8.9261128521907.
# [I 2026-08-20 12:54:00,209] Trial 7 finished with value: 8.11489886468221 and parameters: {'gate_0': 'RZ', 'gate_1': 'I', 'gate_2': 'RX', 'gate_3': 'CNOT', 'gate_4': 'RZ', 'gate_5': 'H', 'gate_6': 'CNOT', 'gate_7': 'H', 'gate_8': 'H', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'RZ', 'gate_15': 'RY'}. Best is trial 3 with value: 8.9261128521907.
# [I 2026-08-20 12:54:02,769] Trial 8 finished with value: 5.394349730109426 and parameters: {'gate_0': 'RZ', 'gate_1': 'I', 'gate_2': 'RX', 'gate_3': 'RX', 'gate_4': 'H', 'gate_5': 'RX', 'gate_6': 'H', 'gate_7': 'RY', 'gate_8': 'RX', 'gate_9': 'RY', 'gate_10': 'CNOT', 'gate_11': 'CNOT', 'gate_12': 'H', 'gate_13': 'RZ', 'gate_14': 'I', 'gate_15': 'CNOT'}. Best is trial 3 with value: 8.9261128521907.
# [I 2026-08-20 12:54:05,365] Trial 9 finished with value: 6.385558037769718 and parameters: {'gate_0': 'RZ', 'gate_1': 'RZ', 'gate_2': 'RZ', 'gate_3': 'I', 'gate_4': 'RX', 'gate_5': 'RX', 'gate_6': 'I', 'gate_7': 'CNOT', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RZ', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'RY', 'gate_14': 'CNOT', 'gate_15': 'RZ'}. Best is trial 3 with value: 8.9261128521907.
# [I 2026-08-20 12:54:08,178] Trial 10 finished with value: 8.577087191145015 and parameters: {'gate_0': 'I', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'H', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'RY', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RX', 'gate_15': 'H'}. Best is trial 3 with value: 8.9261128521907.
# [I 2026-08-20 12:54:11,419] Trial 11 finished with value: 8.679010815633136 and parameters: {'gate_0': 'I', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'H', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'RY', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RX', 'gate_15': 'H'}. Best is trial 3 with value: 8.9261128521907.
# [I 2026-08-20 12:54:13,654] Trial 12 finished with value: 7.678854125688118 and parameters: {'gate_0': 'I', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'H', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'RY', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'H'}. Best is trial 3 with value: 8.9261128521907.
# [I 2026-08-20 12:54:15,676] Trial 13 finished with value: 9.243397064955875 and parameters: {'gate_0': 'RY', 'gate_1': 'RY', 'gate_2': 'H', 'gate_3': 'H', 'gate_4': 'RY', 'gate_5': 'RZ', 'gate_6': 'RZ', 'gate_7': 'RZ', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RY', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'H', 'gate_14': 'RX', 'gate_15': 'I'}. Best is trial 13 with value: 9.243397064955875.
# [I 2026-08-20 12:54:17,536] Trial 14 finished with value: 7.7995038162679755 and parameters: {'gate_0': 'RY', 'gate_1': 'RY', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'I', 'gate_5': 'RZ', 'gate_6': 'RZ', 'gate_7': 'RZ', 'gate_8': 'RZ', 'gate_9': 'I', 'gate_10': 'RY', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'RY', 'gate_14': 'RX', 'gate_15': 'I'}. Best is trial 13 with value: 9.243397064955875.
# [I 2026-08-20 12:54:20,102] Trial 15 finished with value: 7.6381066390319905 and parameters: {'gate_0': 'RY', 'gate_1': 'RY', 'gate_2': 'H', 'gate_3': 'RX', 'gate_4': 'CNOT', 'gate_5': 'RZ', 'gate_6': 'RZ', 'gate_7': 'RZ', 'gate_8': 'H', 'gate_9': 'RY', 'gate_10': 'RY', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'CNOT', 'gate_14': 'RX', 'gate_15': 'I'}. Best is trial 13 with value: 9.243397064955875.
# [I 2026-08-20 12:54:22,324] Trial 16 finished with value: 4.170956376220624 and parameters: {'gate_0': 'H', 'gate_1': 'RX', 'gate_2': 'I', 'gate_3': 'RZ', 'gate_4': 'RX', 'gate_5': 'RZ', 'gate_6': 'RZ', 'gate_7': 'RZ', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'RY', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'RX', 'gate_14': 'CNOT', 'gate_15': 'I'}. Best is trial 13 with value: 9.243397064955875.
# [I 2026-08-20 12:54:24,824] Trial 17 finished with value: 9.728127098894547 and parameters: {'gate_0': 'RY', 'gate_1': 'CNOT', 'gate_2': 'H', 'gate_3': 'H', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'CNOT', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'RZ', 'gate_12': 'CNOT', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:27,532] Trial 18 finished with value: 7.866316595090543 and parameters: {'gate_0': 'RY', 'gate_1': 'CNOT', 'gate_2': 'H', 'gate_3': 'H', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'CNOT', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'RZ', 'gate_12': 'CNOT', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:29,982] Trial 19 finished with value: 7.449841829003987 and parameters: {'gate_0': 'RY', 'gate_1': 'CNOT', 'gate_2': 'H', 'gate_3': 'H', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'CNOT', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'RZ', 'gate_12': 'CNOT', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:32,280] Trial 20 finished with value: 6.975245833091212 and parameters: {'gate_0': 'RY', 'gate_1': 'CNOT', 'gate_2': 'H', 'gate_3': 'I', 'gate_4': 'RY', 'gate_5': 'CNOT', 'gate_6': 'RZ', 'gate_7': 'RX', 'gate_8': 'CNOT', 'gate_9': 'CNOT', 'gate_10': 'H', 'gate_11': 'RZ', 'gate_12': 'CNOT', 'gate_13': 'RZ', 'gate_14': 'RY', 'gate_15': 'I'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:34,270] Trial 21 finished with value: 9.054688196377208 and parameters: {'gate_0': 'H', 'gate_1': 'RY', 'gate_2': 'I', 'gate_3': 'H', 'gate_4': 'I', 'gate_5': 'RZ', 'gate_6': 'RY', 'gate_7': 'RZ', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RY', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'CNOT'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:36,745] Trial 22 finished with value: 8.47117277870524 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RY', 'gate_2': 'I', 'gate_3': 'H', 'gate_4': 'RY', 'gate_5': 'RZ', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RY', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:39,233] Trial 23 finished with value: 6.624567956677902 and parameters: {'gate_0': 'RY', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'H', 'gate_4': 'I', 'gate_5': 'RZ', 'gate_6': 'RZ', 'gate_7': 'RZ', 'gate_8': 'CNOT', 'gate_9': 'RX', 'gate_10': 'RY', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:41,046] Trial 24 finished with value: 6.827036003376196 and parameters: {'gate_0': 'RY', 'gate_1': 'RY', 'gate_2': 'I', 'gate_3': 'H', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'I'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:43,109] Trial 25 finished with value: 8.456694863439862 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'CNOT', 'gate_4': 'CNOT', 'gate_5': 'RZ', 'gate_6': 'RY', 'gate_7': 'RZ', 'gate_8': 'RY', 'gate_9': 'RZ', 'gate_10': 'RY', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'I', 'gate_14': 'H', 'gate_15': 'CNOT'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:45,359] Trial 26 finished with value: 8.208069842184132 and parameters: {'gate_0': 'RY', 'gate_1': 'RX', 'gate_2': 'H', 'gate_3': 'RZ', 'gate_4': 'H', 'gate_5': 'RZ', 'gate_6': 'H', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'RY', 'gate_10': 'RY', 'gate_11': 'RZ', 'gate_12': 'CNOT', 'gate_13': 'RY', 'gate_14': 'H', 'gate_15': 'RZ'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:47,312] Trial 27 finished with value: 8.776682366731848 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'H', 'gate_9': 'I', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'CNOT', 'gate_14': 'RZ', 'gate_15': 'RX'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:49,975] Trial 28 finished with value: 8.647278120343264 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RZ', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'I', 'gate_5': 'RZ', 'gate_6': 'RZ', 'gate_7': 'RZ', 'gate_8': 'CNOT', 'gate_9': 'H', 'gate_10': 'RY', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:52,739] Trial 29 finished with value: 9.180405781384113 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'RX', 'gate_3': 'CNOT', 'gate_4': 'RZ', 'gate_5': 'CNOT', 'gate_6': 'CNOT', 'gate_7': 'CNOT', 'gate_8': 'CNOT', 'gate_9': 'I', 'gate_10': 'H', 'gate_11': 'CNOT', 'gate_12': 'RX', 'gate_13': 'H', 'gate_14': 'RY', 'gate_15': 'RZ'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:55,262] Trial 30 finished with value: 7.563488207561584 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'RX', 'gate_3': 'CNOT', 'gate_4': 'RZ', 'gate_5': 'CNOT', 'gate_6': 'CNOT', 'gate_7': 'CNOT', 'gate_8': 'CNOT', 'gate_9': 'I', 'gate_10': 'H', 'gate_11': 'CNOT', 'gate_12': 'RX', 'gate_13': 'H', 'gate_14': 'RY', 'gate_15': 'RZ'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:54:57,845] Trial 31 finished with value: 7.734754790359986 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'RX', 'gate_3': 'CNOT', 'gate_4': 'RZ', 'gate_5': 'CNOT', 'gate_6': 'CNOT', 'gate_7': 'CNOT', 'gate_8': 'CNOT', 'gate_9': 'I', 'gate_10': 'H', 'gate_11': 'CNOT', 'gate_12': 'RX', 'gate_13': 'H', 'gate_14': 'RY', 'gate_15': 'RZ'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:00,256] Trial 32 finished with value: 8.420951909522993 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'RZ', 'gate_5': 'CNOT', 'gate_6': 'CNOT', 'gate_7': 'CNOT', 'gate_8': 'CNOT', 'gate_9': 'I', 'gate_10': 'H', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'H', 'gate_14': 'RY', 'gate_15': 'RZ'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:02,722] Trial 33 finished with value: 4.799163587294604 and parameters: {'gate_0': 'RX', 'gate_1': 'RY', 'gate_2': 'RX', 'gate_3': 'H', 'gate_4': 'RZ', 'gate_5': 'CNOT', 'gate_6': 'RY', 'gate_7': 'CNOT', 'gate_8': 'RZ', 'gate_9': 'CNOT', 'gate_10': 'H', 'gate_11': 'CNOT', 'gate_12': 'RX', 'gate_13': 'CNOT', 'gate_14': 'RY', 'gate_15': 'I'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:04,778] Trial 34 finished with value: 5.639890141956712 and parameters: {'gate_0': 'H', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'CNOT', 'gate_7': 'RX', 'gate_8': 'CNOT', 'gate_9': 'I', 'gate_10': 'I', 'gate_11': 'CNOT', 'gate_12': 'CNOT', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RZ'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:07,009] Trial 35 finished with value: 8.152550506233258 and parameters: {'gate_0': 'CNOT', 'gate_1': 'H', 'gate_2': 'RX', 'gate_3': 'H', 'gate_4': 'I', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'RZ', 'gate_11': 'RZ', 'gate_12': 'RX', 'gate_13': 'H', 'gate_14': 'RZ', 'gate_15': 'CNOT'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:08,955] Trial 36 finished with value: 6.603591246579974 and parameters: {'gate_0': 'H', 'gate_1': 'RX', 'gate_2': 'RZ', 'gate_3': 'I', 'gate_4': 'H', 'gate_5': 'RZ', 'gate_6': 'H', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'RX', 'gate_10': 'RY', 'gate_11': 'I', 'gate_12': 'I', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RY'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:11,310] Trial 37 finished with value: 8.082248214962219 and parameters: {'gate_0': 'RY', 'gate_1': 'RY', 'gate_2': 'H', 'gate_3': 'H', 'gate_4': 'I', 'gate_5': 'CNOT', 'gate_6': 'RY', 'gate_7': 'CNOT', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'CNOT', 'gate_11': 'H', 'gate_12': 'RZ', 'gate_13': 'H', 'gate_14': 'RX', 'gate_15': 'CNOT'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:13,793] Trial 38 finished with value: 7.704711929192411 and parameters: {'gate_0': 'RX', 'gate_1': 'H', 'gate_2': 'RY', 'gate_3': 'RZ', 'gate_4': 'RZ', 'gate_5': 'H', 'gate_6': 'I', 'gate_7': 'RX', 'gate_8': 'RZ', 'gate_9': 'CNOT', 'gate_10': 'H', 'gate_11': 'CNOT', 'gate_12': 'H', 'gate_13': 'RZ', 'gate_14': 'RY', 'gate_15': 'RX'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:16,256] Trial 39 finished with value: 7.817187559076328 and parameters: {'gate_0': 'H', 'gate_1': 'RZ', 'gate_2': 'RX', 'gate_3': 'H', 'gate_4': 'CNOT', 'gate_5': 'I', 'gate_6': 'CNOT', 'gate_7': 'H', 'gate_8': 'CNOT', 'gate_9': 'RX', 'gate_10': 'RZ', 'gate_11': 'RZ', 'gate_12': 'CNOT', 'gate_13': 'I', 'gate_14': 'RX', 'gate_15': 'RY'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:18,266] Trial 40 finished with value: 8.762928142908834 and parameters: {'gate_0': 'RY', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'RX', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'I', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'I', 'gate_13': 'H', 'gate_14': 'I', 'gate_15': 'CNOT'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:20,577] Trial 41 finished with value: 7.419381474293056 and parameters: {'gate_0': 'H', 'gate_1': 'RY', 'gate_2': 'RY', 'gate_3': 'H', 'gate_4': 'I', 'gate_5': 'RY', 'gate_6': 'RY', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RX', 'gate_15': 'CNOT'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:22,880] Trial 42 finished with value: 7.227125573183446 and parameters: {'gate_0': 'H', 'gate_1': 'RY', 'gate_2': 'RY', 'gate_3': 'H', 'gate_4': 'I', 'gate_5': 'RY', 'gate_6': 'RY', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RX', 'gate_15': 'CNOT'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:25,043] Trial 43 finished with value: 8.000861672748039 and parameters: {'gate_0': 'H', 'gate_1': 'RY', 'gate_2': 'RY', 'gate_3': 'H', 'gate_4': 'I', 'gate_5': 'RY', 'gate_6': 'RY', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'H', 'gate_13': 'H', 'gate_14': 'RX', 'gate_15': 'CNOT'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:27,560] Trial 44 finished with value: 6.4070285687906585 and parameters: {'gate_0': 'RZ', 'gate_1': 'RY', 'gate_2': 'RY', 'gate_3': 'CNOT', 'gate_4': 'I', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'H', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'CNOT', 'gate_11': 'CNOT', 'gate_12': 'RY', 'gate_13': 'RY', 'gate_14': 'RX', 'gate_15': 'H'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:29,895] Trial 45 finished with value: 7.331656117681307 and parameters: {'gate_0': 'I', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'RX', 'gate_6': 'RY', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'RY', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'H', 'gate_14': 'RZ', 'gate_15': 'RZ'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:32,365] Trial 46 finished with value: 7.3174672678580945 and parameters: {'gate_0': 'H', 'gate_1': 'H', 'gate_2': 'RZ', 'gate_3': 'H', 'gate_4': 'RZ', 'gate_5': 'RZ', 'gate_6': 'CNOT', 'gate_7': 'RZ', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'RY', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'CNOT', 'gate_15': 'I'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:35,118] Trial 47 finished with value: 6.4282602757887926 and parameters: {'gate_0': 'RZ', 'gate_1': 'CNOT', 'gate_2': 'RX', 'gate_3': 'I', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'RY', 'gate_7': 'CNOT', 'gate_8': 'RZ', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'RX', 'gate_12': 'RX', 'gate_13': 'RZ', 'gate_14': 'H', 'gate_15': 'CNOT'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:37,519] Trial 48 finished with value: 7.095258410113109 and parameters: {'gate_0': 'I', 'gate_1': 'RZ', 'gate_2': 'I', 'gate_3': 'H', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'RZ', 'gate_11': 'I', 'gate_12': 'CNOT', 'gate_13': 'I', 'gate_14': 'RX', 'gate_15': 'RY'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:40,589] Trial 49 finished with value: 7.250840918978297 and parameters: {'gate_0': 'RY', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'H', 'gate_4': 'I', 'gate_5': 'RZ', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'I', 'gate_9': 'RX', 'gate_10': 'RY', 'gate_11': 'RZ', 'gate_12': 'I', 'gate_13': 'CNOT', 'gate_14': 'I', 'gate_15': 'H'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:43,344] Trial 50 finished with value: 9.457873413559977 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:46,043] Trial 51 finished with value: 7.976970084129424 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 17 with value: 9.728127098894547.
# [I 2026-08-20 12:55:48,837] Trial 52 finished with value: 9.96806913747894 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:55:51,807] Trial 53 finished with value: 7.866914108419333 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:55:54,668] Trial 54 finished with value: 7.755465110321944 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:55:57,340] Trial 55 finished with value: 9.684420069938458 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:00,101] Trial 56 finished with value: 9.469230924653983 and parameters: {'gate_0': 'RY', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'RX', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:02,694] Trial 57 finished with value: 8.889522162550449 and parameters: {'gate_0': 'RY', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'RX', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:05,189] Trial 58 finished with value: 8.578681813449922 and parameters: {'gate_0': 'RY', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'RX', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:07,707] Trial 59 finished with value: 8.229666832185648 and parameters: {'gate_0': 'RY', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'RX', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:10,286] Trial 60 finished with value: 8.089523544243415 and parameters: {'gate_0': 'RY', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RY', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'RX', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:12,862] Trial 61 finished with value: 9.944641191901631 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:15,348] Trial 62 finished with value: 9.773553947121806 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:17,798] Trial 63 finished with value: 8.201872507632352 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'RY', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:20,148] Trial 64 finished with value: 7.9534656915630535 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:22,555] Trial 65 finished with value: 8.855598291116518 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:24,905] Trial 66 finished with value: 8.552144768012676 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'RZ', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:27,156] Trial 67 finished with value: 9.394404031791714 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:29,507] Trial 68 finished with value: 8.080409028809338 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'RX', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:31,843] Trial 69 finished with value: 7.416278775230819 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RZ', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:34,250] Trial 70 finished with value: 7.32063882838777 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'CNOT', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'CNOT', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'CNOT', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:36,654] Trial 71 finished with value: 7.653660777633772 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:38,844] Trial 72 finished with value: 8.239402009536684 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:41,058] Trial 73 finished with value: 9.413528593973568 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:43,240] Trial 74 finished with value: 8.527921909483863 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:45,601] Trial 75 finished with value: 7.620700281384314 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RZ', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RZ', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'H', 'gate_13': 'CNOT', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:47,784] Trial 76 finished with value: 6.484847830524463 and parameters: {'gate_0': 'RZ', 'gate_1': 'RX', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RX', 'gate_5': 'I', 'gate_6': 'I', 'gate_7': 'RY', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RZ', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'CNOT', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:50,274] Trial 77 finished with value: 9.165521493996666 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RX', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'CNOT', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:52,646] Trial 78 finished with value: 7.400391038935674 and parameters: {'gate_0': 'I', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'I', 'gate_12': 'CNOT', 'gate_13': 'RY', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:54,943] Trial 79 finished with value: 8.241558220379872 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'RX', 'gate_6': 'RZ', 'gate_7': 'H', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RZ', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:56:58,107] Trial 80 finished with value: 7.853775793986368 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'CNOT', 'gate_3': 'I', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'H', 'gate_7': 'RY', 'gate_8': 'RX', 'gate_9': 'CNOT', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RZ', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 52 with value: 9.96806913747894.
# [I 2026-08-20 12:57:01,086] Trial 81 finished with value: 10.659472978026098 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 81 with value: 10.659472978026098.
# [I 2026-08-20 12:57:04,228] Trial 82 finished with value: 9.47661660224288 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 81 with value: 10.659472978026098.
# [I 2026-08-20 12:57:07,234] Trial 83 finished with value: 8.326914172084656 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 81 with value: 10.659472978026098.
# [I 2026-08-20 12:57:10,554] Trial 84 finished with value: 7.907846384066609 and parameters: {'gate_0': 'CNOT', 'gate_1': 'H', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RY', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'H'}. Best is trial 81 with value: 10.659472978026098.
# [I 2026-08-20 12:57:15,680] Trial 85 finished with value: 8.186790576961574 and parameters: {'gate_0': 'H', 'gate_1': 'RZ', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 81 with value: 10.659472978026098.
# [I 2026-08-20 12:57:19,578] Trial 86 finished with value: 6.221215134553221 and parameters: {'gate_0': 'RY', 'gate_1': 'RX', 'gate_2': 'H', 'gate_3': 'RZ', 'gate_4': 'CNOT', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'CNOT', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'RZ', 'gate_12': 'CNOT', 'gate_13': 'H', 'gate_14': 'I', 'gate_15': 'RY'}. Best is trial 81 with value: 10.659472978026098.
# [I 2026-08-20 12:57:23,230] Trial 87 finished with value: 8.16760224503026 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'I', 'gate_9': 'RX', 'gate_10': 'RZ', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'RX', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 81 with value: 10.659472978026098.
# [I 2026-08-20 12:57:26,958] Trial 88 finished with value: 7.380108291023327 and parameters: {'gate_0': 'H', 'gate_1': 'CNOT', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RX', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'H', 'gate_13': 'RZ', 'gate_14': 'CNOT', 'gate_15': 'RX'}. Best is trial 81 with value: 10.659472978026098.
# [I 2026-08-20 12:57:30,400] Trial 89 finished with value: 8.896663754507964 and parameters: {'gate_0': 'RZ', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'H', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 81 with value: 10.659472978026098.
# [I 2026-08-20 12:57:33,855] Trial 90 finished with value: 9.230730554935985 and parameters: {'gate_0': 'RY', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'I', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'RX', 'gate_10': 'CNOT', 'gate_11': 'RZ', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 81 with value: 10.659472978026098.
# [I 2026-08-20 12:57:36,940] Trial 91 finished with value: 9.237779117130575 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 81 with value: 10.659472978026098.
# [I 2026-08-20 12:57:40,044] Trial 92 finished with value: 11.602971214490438 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 92 with value: 11.602971214490438.
# [I 2026-08-20 12:57:43,155] Trial 93 finished with value: 9.927562032585264 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 92 with value: 11.602971214490438.
# [I 2026-08-20 12:57:46,463] Trial 94 finished with value: 7.762828182142027 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'RX', 'gate_6': 'RZ', 'gate_7': 'H', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 92 with value: 11.602971214490438.
# [I 2026-08-20 12:57:49,981] Trial 95 finished with value: 8.752298626720147 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'CNOT', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RY', 'gate_13': 'CNOT', 'gate_14': 'RZ', 'gate_15': 'RX'}. Best is trial 92 with value: 11.602971214490438.
# [I 2026-08-20 12:57:52,790] Trial 96 finished with value: 4.57935351985326 and parameters: {'gate_0': 'CNOT', 'gate_1': 'CNOT', 'gate_2': 'CNOT', 'gate_3': 'RY', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'I', 'gate_12': 'RZ', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'I'}. Best is trial 92 with value: 11.602971214490438.
# [I 2026-08-20 12:57:55,425] Trial 97 finished with value: 8.947537190448445 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'H', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'CNOT', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 92 with value: 11.602971214490438.
# [I 2026-08-20 12:57:57,903] Trial 98 finished with value: 6.719328336343184 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'I', 'gate_4': 'RY', 'gate_5': 'H', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RX', 'gate_9': 'RZ', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'H', 'gate_15': 'H'}. Best is trial 92 with value: 11.602971214490438.
# [I 2026-08-20 12:58:01,544] Trial 99 finished with value: 11.59755145594906 and parameters: {'gate_0': 'I', 'gate_1': 'H', 'gate_2': 'H', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'RY', 'gate_8': 'RY', 'gate_9': 'H', 'gate_10': 'RZ', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'RX', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 92 with value: 11.602971214490438.
# Saved candidate  → Results/ModHav Synthetic/optuna2/candidate.pkl
# Computing cross-kernel (test × subset)…
# Saved SVM        → Results/ModHav Synthetic/optuna2/svm.pkl
#
# REPORT: optuna2 | 100 trials
# Best C            : 0.1
# Best CV accuracy  : 0.8333
# Test accuracy     : 0.5833
#               precision    recall  f1-score   support
#
#           -1       0.60      0.50      0.55         6
#            1       0.57      0.67      0.62         6
#
#     accuracy                           0.58        12
#    macro avg       0.59      0.58      0.58        12
# weighted avg       0.59      0.58      0.58        12

# %%
# ── 6. Visualizations ──────────────────────────────────────────────────────────

plot_accuracy(summary, ['test'])
plot_g_best(summary)
# Out:
# Saved → Results/ModHav Synthetic/accuracy_comparison.png
# Saved → Results/ModHav Synthetic/g_best_comparison.png
