# %% [markdown]
# # ModHav Synthetic Dataset

# %%
# ── 0. Imports ─────────────────────────────────────────────────────────────────
from config.config import *
from config.experiments import ExperimentConfig

import src.data.saving as saving
import src.utils.visuals as visuals

from src.data.preprocessing import preprocess_synthetic
from src.data.synthetic import ModHav_synthetic_dataset
from src.data.saving import candidate_exists, svm_exists, load_parameter_train, load_svm_results
from src.data.subsets import subset_random, subset_nystrom_global, subset_nystrom_stratified
from src.kernel.quantum_kernel import quantum_kernel_matrix_cross
from src.optimization.pipeline import get_candidate, get_svm_results
from src.optimization.classical_base import classical_baseline
from src.utils.visuals import *

# %%
# ── 1. Data Import ────────────────────────────────────────────────────────────
X, y = ModHav_synthetic_dataset(seed=45)
X_train, X_test, y_train, y_test = preprocess_synthetic(X, y, N_QUBITS)

print(f"Dataset  : ModHav Synthetic, 20 per class")
print(f"Train    : {X_train.shape}  |  Test: {X_test.shape}")

RESULTS_DIR = 'Results/ModHav Synthetic'
saving.RESULTS_DIR = RESULTS_DIR
visuals.RESULTS_DIR = RESULTS_DIR
# Out:
# Dataset  : ModHav Synthetic, 20 per class
# Train    : (28, 4)  |  Test: (12, 4)

# %%
# ── 2. Dataset structure ─────────────────────────────────────────────────────────
graph_dataset("ModHav Synthetic", X, y, X_train, y_train)

# %%
# ── 3. Experiments ─────────────────────────────────────────────────────────────
# This is the main section to edit. Each ExperimentConfig defines one run.
# Comment out any you don't want to include.
#
# name             → used as the Results subfolder name; must be unique
# optimizer        → 'optuna' or 'mealpy'
# variant          → 'geometric' or 'haar'
# subset_method    → 'random', 'nystrom_global', or 'nystrom_stratified'
# subset_kwargs    → passed to the chosen subset function
# optimizer_kwargs → passed to the chosen optimizer
# load_from        → (optional) load candidate from a different experiment name

EXPERIMENTS: list[ExperimentConfig] = [
    # ──– OPTUNA ────────────────────────────────────────────────────────────────
    ExperimentConfig(
        name             = 'optuna',
        optimizer        = 'optuna',
        variant          = 'haar',
        subset_method    = 'none',
        subset_kwargs    = {'n_sample': N_POINTS, 'seed': SEED},
        optimizer_kwargs = {'n_trials': 100},
    ),
    ExperimentConfig(
        name             = 'optuna2',
        optimizer        = 'optuna',
        variant          = 'haar',
        subset_method    = 'none',
        subset_kwargs    = {'n_sample': N_POINTS, 'seed': SEED},
        optimizer_kwargs = {'n_trials': 100},
    ),
    ExperimentConfig(
        name             = 'optuna3, angles fixed',
        optimizer        = 'optuna',
        variant          = 'haar',
        subset_method    = 'none',
        subset_kwargs    = {'n_sample': N_POINTS, 'seed': SEED},
        optimizer_kwargs = {'n_trials': 100},
    ),
    ExperimentConfig(
        name             = 'optuna4, angles fixed',
        optimizer        = 'optuna',
        variant          = 'haar',
        subset_method    = 'none',
        subset_kwargs    = {'n_sample': N_POINTS, 'seed': SEED},
        optimizer_kwargs = {'n_trials': 100},
    )
]

# %%
# ── 4. Run ─────────────────────────────────────────────────────────────────────
# Cached results are reused automatically; delete Results/{name}/svm.pkl or
# Results/{name}/candidate.pkl to force a fresh run for that experiment.
 
summary = {}   # name → {accuracy, cv_acc, g_best, best_C}

# ── Classical baseline ──────────────────────────────────────────────────────
BASELINE = 'Classical_baseline'
if svm_exists(BASELINE):
    print(f"\nLoaded results of SVM for '{BASELINE}'")
    baseline_res = load_svm_results(BASELINE)
else:
    baseline_res = classical_baseline(X_train, y_train, X_test, y_test, name=BASELINE)
 
summary[BASELINE] = {
    'accuracy': baseline_res['accuracy'],
    'cv_acc':   float(baseline_res['best_cv_accuracy']),
    'best_C':   baseline_res['best_C'],
    'g_best':   float('nan'),
}

# ── Quantum experiments ─────────────────────────────────────────────────────
for config in EXPERIMENTS:
    print(f"\n{'─' * 60}")
    print(f" {config.name}  [{config.optimizer} + {config.subset_method}]")
    print(f"{'─' * 60}")

    # Step 1: Candidate (train or load from cache)
    candidate, K_train, K_classical, X_sub, y_sub = get_candidate(config, X_train, y_train)
    g_best = load_parameter_train(config.load_from or config.name).get('g_best', float('nan'))
    
    # Step 2: SVM (run or load from cache)
    K_test = None
    if not svm_exists(config.name):
        print("Computing cross-kernel (test × subset)…")
        K_test = quantum_kernel_matrix_cross(X_test, X_sub, candidate)
    
    results = get_svm_results(config, K_train, y_sub, K_test, y_test)
    
    summary[config.name] = {
        'accuracy': results['accuracy'],
        'cv_acc':   float(results['best_cv_accuracy']),
        'best_C':   results['best_C'],
        'g_best':   g_best,
    }
# Out:
# [I 2026-08-20 13:34:41,562] A new study created in memory with name: no-name-4c0a9e18-3697-4386-ad50-017f0c79660e
# Loaded results of SVM for 'Classical_baseline'
#
# ────────────────────────────────────────────────────────────
#  optuna  [optuna + none]
# ────────────────────────────────────────────────────────────
# Loading cached candidate for 'optuna'
# Loading cached SVM results for 'optuna'
#
# ────────────────────────────────────────────────────────────
#  optuna2  [optuna + none]
# ────────────────────────────────────────────────────────────
# Loading cached candidate for 'optuna2'
# Loading cached SVM results for 'optuna2'
#
# ────────────────────────────────────────────────────────────
#  optuna3, angles fixed  [optuna + none]
# ────────────────────────────────────────────────────────────
# Loading cached candidate for 'optuna3, angles fixed'
# Loading cached SVM results for 'optuna3, angles fixed'
#
# ────────────────────────────────────────────────────────────
#  optuna4, angles fixed  [optuna + none]
# ────────────────────────────────────────────────────────────
# [I 2026-08-20 13:34:44,700] Trial 0 finished with value: 9.24288202807043 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'H', 'gate_4': 'H', 'gate_5': 'CNOT', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'RY', 'gate_9': 'CNOT', 'gate_10': 'RZ', 'gate_11': 'I', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RZ', 'gate_15': 'CNOT'}. Best is trial 0 with value: 9.24288202807043.
# [I 2026-08-20 13:34:47,219] Trial 1 finished with value: 6.397342500864165 and parameters: {'gate_0': 'RZ', 'gate_1': 'RZ', 'gate_2': 'CNOT', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'RY', 'gate_6': 'RY', 'gate_7': 'RZ', 'gate_8': 'H', 'gate_9': 'RX', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'CNOT', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 0 with value: 9.24288202807043.
# [I 2026-08-20 13:34:49,366] Trial 2 finished with value: 9.712519135326417 and parameters: {'gate_0': 'H', 'gate_1': 'CNOT', 'gate_2': 'RZ', 'gate_3': 'RX', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'CNOT', 'gate_9': 'RZ', 'gate_10': 'RY', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'RY', 'gate_15': 'RX'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:34:51,775] Trial 3 finished with value: 8.416526723664223 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RZ', 'gate_2': 'RY', 'gate_3': 'RZ', 'gate_4': 'CNOT', 'gate_5': 'RZ', 'gate_6': 'RZ', 'gate_7': 'I', 'gate_8': 'RY', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'RX', 'gate_14': 'RY', 'gate_15': 'RZ'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:34:53,977] Trial 4 finished with value: 6.987757815640987 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RX', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'H', 'gate_5': 'CNOT', 'gate_6': 'I', 'gate_7': 'H', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'CNOT', 'gate_11': 'RX', 'gate_12': 'I', 'gate_13': 'I', 'gate_14': 'RY', 'gate_15': 'RZ'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:34:56,371] Trial 5 finished with value: 6.5066510275657095 and parameters: {'gate_0': 'RZ', 'gate_1': 'H', 'gate_2': 'I', 'gate_3': 'RY', 'gate_4': 'RZ', 'gate_5': 'RZ', 'gate_6': 'RY', 'gate_7': 'H', 'gate_8': 'RY', 'gate_9': 'I', 'gate_10': 'RZ', 'gate_11': 'RY', 'gate_12': 'CNOT', 'gate_13': 'CNOT', 'gate_14': 'I', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:34:59,070] Trial 6 finished with value: 7.85342019455045 and parameters: {'gate_0': 'RY', 'gate_1': 'H', 'gate_2': 'RZ', 'gate_3': 'RY', 'gate_4': 'RX', 'gate_5': 'H', 'gate_6': 'CNOT', 'gate_7': 'RY', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RX', 'gate_13': 'H', 'gate_14': 'I', 'gate_15': 'H'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:01,633] Trial 7 finished with value: 7.2705766914229235 and parameters: {'gate_0': 'H', 'gate_1': 'H', 'gate_2': 'RZ', 'gate_3': 'H', 'gate_4': 'RZ', 'gate_5': 'RX', 'gate_6': 'RZ', 'gate_7': 'I', 'gate_8': 'I', 'gate_9': 'H', 'gate_10': 'RZ', 'gate_11': 'RX', 'gate_12': 'RX', 'gate_13': 'RY', 'gate_14': 'RZ', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:04,577] Trial 8 finished with value: 9.029325188720826 and parameters: {'gate_0': 'RX', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'RX', 'gate_11': 'RX', 'gate_12': 'H', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:07,451] Trial 9 finished with value: 8.43261026466407 and parameters: {'gate_0': 'CNOT', 'gate_1': 'H', 'gate_2': 'RZ', 'gate_3': 'RY', 'gate_4': 'RX', 'gate_5': 'RZ', 'gate_6': 'RY', 'gate_7': 'RZ', 'gate_8': 'RZ', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RY', 'gate_13': 'RZ', 'gate_14': 'RZ', 'gate_15': 'RZ'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:10,647] Trial 10 finished with value: 8.175289024440326 and parameters: {'gate_0': 'H', 'gate_1': 'CNOT', 'gate_2': 'RX', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'I', 'gate_6': 'H', 'gate_7': 'CNOT', 'gate_8': 'CNOT', 'gate_9': 'RY', 'gate_10': 'RY', 'gate_11': 'H', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'RX', 'gate_15': 'RX'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:13,395] Trial 11 finished with value: 5.629452425133023 and parameters: {'gate_0': 'I', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'H', 'gate_4': 'I', 'gate_5': 'CNOT', 'gate_6': 'H', 'gate_7': 'RX', 'gate_8': 'CNOT', 'gate_9': 'CNOT', 'gate_10': 'H', 'gate_11': 'CNOT', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RY', 'gate_15': 'I'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:15,661] Trial 12 finished with value: 6.919598315415186 and parameters: {'gate_0': 'H', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'I', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'I', 'gate_8': 'RY', 'gate_9': 'CNOT', 'gate_10': 'RY', 'gate_11': 'RZ', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RZ', 'gate_15': 'RY'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:17,971] Trial 13 finished with value: 6.957923430573291 and parameters: {'gate_0': 'I', 'gate_1': 'CNOT', 'gate_2': 'H', 'gate_3': 'H', 'gate_4': 'H', 'gate_5': 'CNOT', 'gate_6': 'H', 'gate_7': 'H', 'gate_8': 'CNOT', 'gate_9': 'CNOT', 'gate_10': 'RY', 'gate_11': 'I', 'gate_12': 'RY', 'gate_13': 'RX', 'gate_14': 'RX', 'gate_15': 'RX'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:20,151] Trial 14 finished with value: 7.8073607767509285 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'H', 'gate_3': 'RX', 'gate_4': 'I', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'RX', 'gate_8': 'H', 'gate_9': 'RZ', 'gate_10': 'RZ', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RY', 'gate_14': 'H', 'gate_15': 'I'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:22,675] Trial 15 finished with value: 7.164331127517731 and parameters: {'gate_0': 'RY', 'gate_1': 'RY', 'gate_2': 'RY', 'gate_3': 'I', 'gate_4': 'CNOT', 'gate_5': 'RX', 'gate_6': 'CNOT', 'gate_7': 'RY', 'gate_8': 'I', 'gate_9': 'RX', 'gate_10': 'H', 'gate_11': 'CNOT', 'gate_12': 'H', 'gate_13': 'H', 'gate_14': 'CNOT', 'gate_15': 'RY'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:24,935] Trial 16 finished with value: 7.499175200638487 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RX', 'gate_2': 'RX', 'gate_3': 'RZ', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'CNOT', 'gate_8': 'RY', 'gate_9': 'RY', 'gate_10': 'I', 'gate_11': 'RZ', 'gate_12': 'I', 'gate_13': 'RZ', 'gate_14': 'RZ', 'gate_15': 'H'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:27,283] Trial 17 finished with value: 4.418958830530349 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'CNOT', 'gate_3': 'H', 'gate_4': 'H', 'gate_5': 'CNOT', 'gate_6': 'H', 'gate_7': 'H', 'gate_8': 'CNOT', 'gate_9': 'CNOT', 'gate_10': 'CNOT', 'gate_11': 'H', 'gate_12': 'CNOT', 'gate_13': 'I', 'gate_14': 'RY', 'gate_15': 'RX'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:29,665] Trial 18 finished with value: 7.705708577903787 and parameters: {'gate_0': 'H', 'gate_1': 'CNOT', 'gate_2': 'CNOT', 'gate_3': 'RX', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'I', 'gate_8': 'CNOT', 'gate_9': 'RZ', 'gate_10': 'RY', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'RZ', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:32,281] Trial 19 finished with value: 6.070322260313674 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RY', 'gate_2': 'RZ', 'gate_3': 'H', 'gate_4': 'H', 'gate_5': 'CNOT', 'gate_6': 'H', 'gate_7': 'H', 'gate_8': 'RY', 'gate_9': 'CNOT', 'gate_10': 'RZ', 'gate_11': 'I', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RY', 'gate_15': 'RX'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:34,216] Trial 20 finished with value: 7.8189299544171025 and parameters: {'gate_0': 'I', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RZ', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'I', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RY', 'gate_11': 'I', 'gate_12': 'RY', 'gate_13': 'RZ', 'gate_14': 'H', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:37,109] Trial 21 finished with value: 8.999284433937753 and parameters: {'gate_0': 'RX', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'RX', 'gate_11': 'RX', 'gate_12': 'H', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:40,183] Trial 22 finished with value: 9.026098320741875 and parameters: {'gate_0': 'RX', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'RZ', 'gate_11': 'RY', 'gate_12': 'H', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:43,058] Trial 23 finished with value: 8.139057286382952 and parameters: {'gate_0': 'RX', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'RX', 'gate_11': 'RX', 'gate_12': 'H', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:45,739] Trial 24 finished with value: 6.014093089624086 and parameters: {'gate_0': 'RX', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'RX', 'gate_9': 'RY', 'gate_10': 'H', 'gate_11': 'RZ', 'gate_12': 'H', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:48,713] Trial 25 finished with value: 7.231600168280467 and parameters: {'gate_0': 'RY', 'gate_1': 'RY', 'gate_2': 'H', 'gate_3': 'RZ', 'gate_4': 'CNOT', 'gate_5': 'RX', 'gate_6': 'RZ', 'gate_7': 'CNOT', 'gate_8': 'RZ', 'gate_9': 'RX', 'gate_10': 'I', 'gate_11': 'H', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'RX', 'gate_15': 'I'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:51,271] Trial 26 finished with value: 6.534267513540143 and parameters: {'gate_0': 'RZ', 'gate_1': 'RZ', 'gate_2': 'RX', 'gate_3': 'I', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'RX', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'CNOT', 'gate_11': 'CNOT', 'gate_12': 'I', 'gate_13': 'RY', 'gate_14': 'I', 'gate_15': 'H'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:54,228] Trial 27 finished with value: 8.214732581753037 and parameters: {'gate_0': 'RX', 'gate_1': 'RX', 'gate_2': 'RY', 'gate_3': 'RX', 'gate_4': 'I', 'gate_5': 'H', 'gate_6': 'CNOT', 'gate_7': 'I', 'gate_8': 'CNOT', 'gate_9': 'RZ', 'gate_10': 'RZ', 'gate_11': 'I', 'gate_12': 'CNOT', 'gate_13': 'CNOT', 'gate_14': 'RY', 'gate_15': 'RY'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:35:57,463] Trial 28 finished with value: 8.123968719196892 and parameters: {'gate_0': 'H', 'gate_1': 'CNOT', 'gate_2': 'CNOT', 'gate_3': 'H', 'gate_4': 'RX', 'gate_5': 'CNOT', 'gate_6': 'H', 'gate_7': 'H', 'gate_8': 'RY', 'gate_9': 'CNOT', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'H', 'gate_13': 'H', 'gate_14': 'RZ', 'gate_15': 'RX'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:00,845] Trial 29 finished with value: 8.918072163893845 and parameters: {'gate_0': 'RZ', 'gate_1': 'RZ', 'gate_2': 'CNOT', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'RY', 'gate_6': 'RY', 'gate_7': 'RZ', 'gate_8': 'H', 'gate_9': 'RX', 'gate_10': 'RY', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'CNOT', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:03,784] Trial 30 finished with value: 9.363593120679317 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:06,736] Trial 31 finished with value: 7.855455473740045 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:09,771] Trial 32 finished with value: 9.267947853179553 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:12,739] Trial 33 finished with value: 8.274684753441994 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:15,824] Trial 34 finished with value: 6.489299998066724 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RY', 'gate_2': 'RY', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'RZ', 'gate_6': 'RZ', 'gate_7': 'RZ', 'gate_8': 'RY', 'gate_9': 'I', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'RY', 'gate_15': 'RZ'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:19,286] Trial 35 finished with value: 8.018744334982612 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RZ', 'gate_2': 'I', 'gate_3': 'RZ', 'gate_4': 'CNOT', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'RX', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'RX', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:22,022] Trial 36 finished with value: 7.378833065100518 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'RY', 'gate_4': 'RZ', 'gate_5': 'CNOT', 'gate_6': 'I', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'CNOT', 'gate_11': 'RY', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'I', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:25,157] Trial 37 finished with value: 7.409758609373265 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RX', 'gate_2': 'RZ', 'gate_3': 'RX', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RY', 'gate_7': 'RY', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'RZ', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'CNOT', 'gate_14': 'RY', 'gate_15': 'RZ'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:28,265] Trial 38 finished with value: 6.374391925793752 and parameters: {'gate_0': 'CNOT', 'gate_1': 'H', 'gate_2': 'RZ', 'gate_3': 'H', 'gate_4': 'RX', 'gate_5': 'RZ', 'gate_6': 'CNOT', 'gate_7': 'RZ', 'gate_8': 'RY', 'gate_9': 'I', 'gate_10': 'I', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RZ', 'gate_15': 'CNOT'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:30,745] Trial 39 finished with value: 9.516747085697556 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'H'}. Best is trial 2 with value: 9.712519135326417.
# [I 2026-08-20 13:36:33,128] Trial 40 finished with value: 10.658587453131233 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:36:35,494] Trial 41 finished with value: 7.797019673367649 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:36:37,862] Trial 42 finished with value: 8.567416520495764 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:36:40,201] Trial 43 finished with value: 9.948568171698868 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:36:42,425] Trial 44 finished with value: 3.897805967276113 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'H', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:36:44,739] Trial 45 finished with value: 9.234041585276604 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'RY', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:36:46,823] Trial 46 finished with value: 6.573381619503516 and parameters: {'gate_0': 'RY', 'gate_1': 'I', 'gate_2': 'I', 'gate_3': 'RY', 'gate_4': 'I', 'gate_5': 'H', 'gate_6': 'RZ', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:36:49,311] Trial 47 finished with value: 7.19509019928163 and parameters: {'gate_0': 'RZ', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RY', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'RY', 'gate_14': 'RX', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:36:51,126] Trial 48 finished with value: 3.2808695683247655 and parameters: {'gate_0': 'I', 'gate_1': 'H', 'gate_2': 'I', 'gate_3': 'I', 'gate_4': 'RZ', 'gate_5': 'H', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'H', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'RZ', 'gate_14': 'CNOT', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:36:53,361] Trial 49 finished with value: 8.74383125044888 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'H', 'gate_6': 'RY', 'gate_7': 'RX', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'CNOT', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'I', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:36:55,874] Trial 50 finished with value: 8.654748577412073 and parameters: {'gate_0': 'H', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'CNOT', 'gate_8': 'CNOT', 'gate_9': 'RZ', 'gate_10': 'RY', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'I', 'gate_14': 'RY', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:36:58,333] Trial 51 finished with value: 9.220126380914424 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'RX', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'RX', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'I', 'gate_9': 'RY', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'I'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:00,982] Trial 52 finished with value: 7.448904401155609 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'CNOT', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'RZ', 'gate_12': 'CNOT', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:03,065] Trial 53 finished with value: 6.75074837469159 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'I', 'gate_8': 'I', 'gate_9': 'H', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'RY'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:05,342] Trial 54 finished with value: 8.675686432337567 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'I', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:07,778] Trial 55 finished with value: 5.468989006306515 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'RX', 'gate_4': 'CNOT', 'gate_5': 'H', 'gate_6': 'H', 'gate_7': 'H', 'gate_8': 'RZ', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RY', 'gate_13': 'RX', 'gate_14': 'H', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:10,251] Trial 56 finished with value: 7.561775038233561 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'RY', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'RZ', 'gate_6': 'RX', 'gate_7': 'RY', 'gate_8': 'I', 'gate_9': 'RX', 'gate_10': 'RY', 'gate_11': 'RY', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'RZ'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:12,494] Trial 57 finished with value: 4.682412761972047 and parameters: {'gate_0': 'CNOT', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RZ', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'I', 'gate_7': 'RZ', 'gate_8': 'H', 'gate_9': 'RZ', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RZ', 'gate_13': 'RZ', 'gate_14': 'CNOT', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:14,653] Trial 58 finished with value: 8.067293879247929 and parameters: {'gate_0': 'I', 'gate_1': 'RX', 'gate_2': 'RZ', 'gate_3': 'RY', 'gate_4': 'I', 'gate_5': 'RY', 'gate_6': 'CNOT', 'gate_7': 'CNOT', 'gate_8': 'CNOT', 'gate_9': 'I', 'gate_10': 'CNOT', 'gate_11': 'H', 'gate_12': 'I', 'gate_13': 'I', 'gate_14': 'RX', 'gate_15': 'I'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:17,319] Trial 59 finished with value: 7.916165146245741 and parameters: {'gate_0': 'RY', 'gate_1': 'I', 'gate_2': 'H', 'gate_3': 'CNOT', 'gate_4': 'RY', 'gate_5': 'RX', 'gate_6': 'RX', 'gate_7': 'RX', 'gate_8': 'RX', 'gate_9': 'RY', 'gate_10': 'I', 'gate_11': 'CNOT', 'gate_12': 'RY', 'gate_13': 'RY', 'gate_14': 'RY', 'gate_15': 'H'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:19,518] Trial 60 finished with value: 8.990700083121617 and parameters: {'gate_0': 'CNOT', 'gate_1': 'H', 'gate_2': 'RX', 'gate_3': 'I', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'I', 'gate_8': 'I', 'gate_9': 'RZ', 'gate_10': 'H', 'gate_11': 'RZ', 'gate_12': 'CNOT', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:22,317] Trial 61 finished with value: 7.9350508599779275 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'H', 'gate_4': 'H', 'gate_5': 'CNOT', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'RY', 'gate_9': 'CNOT', 'gate_10': 'RZ', 'gate_11': 'I', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RZ', 'gate_15': 'CNOT'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:25,115] Trial 62 finished with value: 7.8531899741975915 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'H', 'gate_4': 'H', 'gate_5': 'CNOT', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'RY', 'gate_9': 'CNOT', 'gate_10': 'RZ', 'gate_11': 'I', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RZ', 'gate_15': 'CNOT'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:27,807] Trial 63 finished with value: 8.83463732519119 and parameters: {'gate_0': 'H', 'gate_1': 'RZ', 'gate_2': 'CNOT', 'gate_3': 'RX', 'gate_4': 'H', 'gate_5': 'CNOT', 'gate_6': 'H', 'gate_7': 'H', 'gate_8': 'CNOT', 'gate_9': 'CNOT', 'gate_10': 'RZ', 'gate_11': 'I', 'gate_12': 'RY', 'gate_13': 'H', 'gate_14': 'RZ', 'gate_15': 'CNOT'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:30,689] Trial 64 finished with value: 8.27100425986715 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RY', 'gate_2': 'RZ', 'gate_3': 'H', 'gate_4': 'H', 'gate_5': 'H', 'gate_6': 'RX', 'gate_7': 'RZ', 'gate_8': 'RX', 'gate_9': 'CNOT', 'gate_10': 'RX', 'gate_11': 'RX', 'gate_12': 'RY', 'gate_13': 'CNOT', 'gate_14': 'H', 'gate_15': 'RY'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:33,237] Trial 65 finished with value: 7.304703237362487 and parameters: {'gate_0': 'RZ', 'gate_1': 'CNOT', 'gate_2': 'RZ', 'gate_3': 'CNOT', 'gate_4': 'RZ', 'gate_5': 'I', 'gate_6': 'RZ', 'gate_7': 'H', 'gate_8': 'RY', 'gate_9': 'I', 'gate_10': 'RY', 'gate_11': 'RY', 'gate_12': 'RX', 'gate_13': 'I', 'gate_14': 'CNOT', 'gate_15': 'CNOT'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:35,454] Trial 66 finished with value: 7.335653324447767 and parameters: {'gate_0': 'CNOT', 'gate_1': 'I', 'gate_2': 'I', 'gate_3': 'CNOT', 'gate_4': 'H', 'gate_5': 'I', 'gate_6': 'RX', 'gate_7': 'H', 'gate_8': 'RX', 'gate_9': 'RX', 'gate_10': 'RX', 'gate_11': 'I', 'gate_12': 'RY', 'gate_13': 'I', 'gate_14': 'RY', 'gate_15': 'CNOT'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:38,054] Trial 67 finished with value: 9.57081019433288 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'RX', 'gate_4': 'H', 'gate_5': 'RY', 'gate_6': 'RX', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:40,639] Trial 68 finished with value: 8.783544875350328 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RY', 'gate_2': 'CNOT', 'gate_3': 'RX', 'gate_4': 'H', 'gate_5': 'RY', 'gate_6': 'RX', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:43,067] Trial 69 finished with value: 6.653957779496342 and parameters: {'gate_0': 'H', 'gate_1': 'I', 'gate_2': 'RZ', 'gate_3': 'RX', 'gate_4': 'CNOT', 'gate_5': 'RY', 'gate_6': 'RY', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:45,469] Trial 70 finished with value: 9.55395493076235 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RX', 'gate_2': 'RY', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:47,983] Trial 71 finished with value: 6.671005417454133 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RX', 'gate_2': 'RY', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:50,450] Trial 72 finished with value: 9.55194742649011 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RX', 'gate_2': 'RY', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:52,950] Trial 73 finished with value: 7.982062225511842 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RX', 'gate_2': 'RY', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:55,415] Trial 74 finished with value: 8.62776922486171 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RX', 'gate_2': 'RY', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:37:57,923] Trial 75 finished with value: 7.109115320463959 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RX', 'gate_2': 'RY', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:00,257] Trial 76 finished with value: 6.5640257497276036 and parameters: {'gate_0': 'I', 'gate_1': 'RX', 'gate_2': 'RY', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'CNOT', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:02,708] Trial 77 finished with value: 9.218616202009215 and parameters: {'gate_0': 'CNOT', 'gate_1': 'RX', 'gate_2': 'RY', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'RX', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:05,058] Trial 78 finished with value: 8.393375159986988 and parameters: {'gate_0': 'RY', 'gate_1': 'RX', 'gate_2': 'RY', 'gate_3': 'RX', 'gate_4': 'RX', 'gate_5': 'RY', 'gate_6': 'I', 'gate_7': 'I', 'gate_8': 'H', 'gate_9': 'H', 'gate_10': 'RY', 'gate_11': 'RY', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:07,496] Trial 79 finished with value: 9.758600559780565 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:09,959] Trial 80 finished with value: 7.810255201044391 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'CNOT', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:12,379] Trial 81 finished with value: 7.906750929514459 and parameters: {'gate_0': 'CNOT', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:14,842] Trial 82 finished with value: 10.441893824963385 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:17,213] Trial 83 finished with value: 7.911114391122664 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:19,585] Trial 84 finished with value: 9.612047908637617 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:21,949] Trial 85 finished with value: 9.696239678131448 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:24,401] Trial 86 finished with value: 9.104633499771474 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:26,761] Trial 87 finished with value: 6.93299881766219 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:29,137] Trial 88 finished with value: 7.815143518816229 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:31,513] Trial 89 finished with value: 10.288839555877166 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:33,926] Trial 90 finished with value: 7.586402713675094 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RZ', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:36,294] Trial 91 finished with value: 9.544181341793887 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:38,661] Trial 92 finished with value: 9.20517948902527 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:41,122] Trial 93 finished with value: 8.00230134147465 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:43,588] Trial 94 finished with value: 7.303598505315746 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RZ', 'gate_6': 'H', 'gate_7': 'RY', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'H', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RZ'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:46,155] Trial 95 finished with value: 8.808091938842665 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'RY', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RZ', 'gate_14': 'RY', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:48,623] Trial 96 finished with value: 8.390364708522558 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'RX', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'I', 'gate_13': 'RY', 'gate_14': 'RX', 'gate_15': 'I'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:51,640] Trial 97 finished with value: 8.245548412730958 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'RX', 'gate_3': 'RY', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'CNOT', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'CNOT', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:54,090] Trial 98 finished with value: 6.676546921594494 and parameters: {'gate_0': 'RX', 'gate_1': 'CNOT', 'gate_2': 'H', 'gate_3': 'I', 'gate_4': 'I', 'gate_5': 'RX', 'gate_6': 'CNOT', 'gate_7': 'I', 'gate_8': 'CNOT', 'gate_9': 'RZ', 'gate_10': 'I', 'gate_11': 'RX', 'gate_12': 'RZ', 'gate_13': 'RX', 'gate_14': 'I', 'gate_15': 'RY'}. Best is trial 40 with value: 10.658587453131233.
# [I 2026-08-20 13:38:56,640] Trial 99 finished with value: 7.657860507844097 and parameters: {'gate_0': 'RX', 'gate_1': 'RZ', 'gate_2': 'I', 'gate_3': 'RX', 'gate_4': 'RY', 'gate_5': 'RY', 'gate_6': 'H', 'gate_7': 'I', 'gate_8': 'RZ', 'gate_9': 'H', 'gate_10': 'H', 'gate_11': 'H', 'gate_12': 'RZ', 'gate_13': 'CNOT', 'gate_14': 'RY', 'gate_15': 'RX'}. Best is trial 40 with value: 10.658587453131233.
# Saved candidate  → Results/ModHav Synthetic/optuna4, angles fixed/candidate.pkl
# Computing cross-kernel (test × subset)…
# Saved SVM        → Results/ModHav Synthetic/optuna4, angles fixed/svm.pkl
#
# REPORT: optuna4, angles fixed | 100 trials
# Best C            : 0.1
# Best CV accuracy  : 0.6000
# Test accuracy     : 0.5000
#               precision    recall  f1-score   support
#
#           -1       0.50      0.33      0.40         6
#            1       0.50      0.67      0.57         6
#
#     accuracy                           0.50        12
#    macro avg       0.50      0.50      0.49        12
# weighted avg       0.50      0.50      0.49        12

# %%
# ── 6. Visualizations ──────────────────────────────────────────────────────────

plot_accuracy(summary, ['test'])
plot_g_best(summary)
# Out:
# Saved → Results/ModHav Synthetic/accuracy_comparison.png
# Saved → Results/ModHav Synthetic/g_best_comparison.png
